# %%
import pandas as pd
import seaborn as sns
#A
df= sns.load_dataset('penguins')
print(df)
#B
num_observe =df.shape[0]
num_attributes =df.shape[1]
print(f"\nno. of obervation:",num_observe)
print(f"\nno. of attributes:",num_attributes)
#C
print("\nattributes,row index,and data types:",df.info())
print(df.columns.tolist())
#D
print("\nfirst 5 records:",df.head())
print("\nlast 5 records:",df.tail())
#E
second_column_values=df.iloc[2:4, 1]
print("\nsecond column value for 3rd and 4th records:",second_column_values)
#F
print("\nsummary of the data distribution:",df.describe())
#G
correlation_matrix = df.corr
print("\npariwise correlation between numerical attibutes:",correlation_matrix)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...
